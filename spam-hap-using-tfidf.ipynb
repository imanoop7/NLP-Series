# %%
import pandas as pd
messages = pd.read_csv('SMSSpamCollection.txt', sep='\t',names=["label", "message"])

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anoop\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# lemetization
corpus = []
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()
    review = review.split()
    
    review = [lemmatizer.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
y= pd.get_dummies(messages['label']).astype(int)
y = y.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(corpus,y, test_size = 0.20, random_state = 0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=2500, ngram_range=(1,2))

# %%
X_train= tfidf.fit_transform(X_train).toarray()
X_test = tfidf.transform(X_test).toarray()

# %%
tfidf.vocabulary_
# Out:
# {'good': 836,
#  'movie': 1365,
#  'ok': 1480,
#  'leave': 1127,
#  'free': 728,
#  'give': 801,
#  'otherwise': 1518,
#  'something': 1933,
#  'maybe': 1270,
#  'bit': 180,
#  'got': 851,
#  'home': 957,
#  'babe': 133,
#  'still': 1989,
#  'awake': 123,
#  'since': 1893,
#  'already': 52,
#  'workin': 2438,
#  'get': 783,
#  'job': 1051,
#  'said': 1785,
#  'matter': 1261,
#  'mind': 1306,
#  'saying': 1801,
#  'oh': 1477,
#  'yeah': 2478,
#  'diet': 533,
#  'oh yeah': 1479,
#  'sorry': 1944,
#  'thing': 2111,
#  'may': 1268,
#  'pub': 1664,
#  'later': 1108,
#  'ill': 1000,
#  'call': 246,
#  'evening': 635,
#  'idea': 994,
#  'dear': 505,
#  'room': 1770,
#  'look': 1186,
#  'daddy': 479,
#  'want': 2345,
#  'eat': 592,
#  'night': 1436,
#  'long': 1183,
#  'chennai': 334,
#  'surely': 2040,
#  'pick': 1571,
#  'competition': 398,
#  'da': 475,
#  'car': 293,
#  'park': 1532,
#  'da car': 476,
#  'okay': 1490,
#  'soon': 1941,
#  'best': 168,
#  'yar': 2476,
#  'else': 602,
#  'thk': 2120,
#  'sort': 1948,
#  'funny': 764,
#  'yup': 2498,
#  'izzit': 1042,
#  'raining': 1684,
#  'co': 363,
#  'mrt': 1371,
#  'outside': 1519,
#  'way': 2365,
#  'ur': 2254,
#  'ur home': 2263,
#  'ask': 103,
#  'bout': 207,
#  'around': 94,
#  'wen': 2391,
#  'girl': 800,
#  'come': 385,
#  'talk': 2058,
#  'cool': 429,
#  'tyler': 2230,
#  'take': 2052,
#  'gonna': 834,
#  'buy': 236,
#  'drop': 576,
#  'place': 1584,
#  'tonight': 2174,
#  'order': 1512,
#  'enough': 618,
#  'later tonight': 1110,
#  'got enough': 852,
#  'work': 2437,
#  'timing': 2147,
#  'village': 2315,
#  'near': 1410,
#  'house': 972,
#  'would': 2448,
#  'woke': 2429,
#  'pls': 1597,
#  'family': 663,
#  'hot': 969,
#  'sun': 2028,
#  'reason': 1710,
#  'going': 829,
#  'invited': 1026,
#  'actually': 15,
#  'go': 809,
#  'wait': 2331,
#  'serious': 1848,
#  'whats': 2396,
#  'coming': 392,
#  'hill': 941,
#  'hope': 960,
#  'great': 861,
#  'day': 492,
#  'fine': 698,
#  'busy': 235,
#  'though': 2123,
#  'hope great': 962,
#  'great day': 862,
#  'many': 1247,
#  'company': 397,
#  'tell': 2076,
#  'honey': 959,
#  'find': 693,
#  'much': 1380,
#  'sell': 1833,
#  'nigeria': 1435,
#  'time': 2138,
#  'used': 2292,
#  'important': 1006,
#  'reply': 1737,
#  'monday': 1350,
#  'many time': 1249,
#  'aight': 38,
#  'lemme': 1134,
#  'know': 1085,
#  'lemme know': 1135,
#  'today': 2157,
#  'plan': 1585,
#  'ok ok': 1484,
#  'ready': 1705,
#  'moan': 1329,
#  'scream': 1806,
#  'get ready': 788,
#  'right': 1759,
#  'make': 1238,
#  'sure': 2038,
#  'load': 1170,
#  'really': 1707,
#  'help': 928,
#  'make sure': 1240,
#  'mobile': 1332,
#  'month': 1352,
#  'entitled': 622,
#  'update': 2250,
#  'latest': 1111,
#  'colour': 380,
#  'camera': 281,
#  'entitled update': 623,
#  'update latest': 2252,
#  'latest colour': 1113,
#  'free call': 730,
#  'call mobile': 260,
#  'mobile update': 1341,
#  'update co': 2251,
#  'co free': 364,
#  'sky': 1905,
#  'quite': 1676,
#  'dark': 483,
#  'liao': 1143,
#  'excuse': 649,
#  'run': 1778,
#  'rite': 1765,
#  'hee': 923,
#  'love': 1203,
#  'working': 2439,
#  'sat': 1792,
#  'wan': 2339,
#  'watch': 2359,
#  'affair': 24,
#  'wif': 2405,
#  'darren': 487,
#  'mayb': 1269,
#  'xy': 2471,
#  'wan watch': 2342,
#  'hello': 927,
#  'news': 1429,
#  'making': 1242,
#  'week': 2377,
#  'im': 1001,
#  'thanks': 2102,
#  'subscription': 2022,
#  'ringtone': 1762,
#  'uk': 2233,
#  'charged': 325,
#  'please': 1592,
#  'confirm': 408,
#  'replying': 1743,
#  'yes': 2482,
#  'mobile charged': 1334,
#  'dunno': 584,
#  'late': 1107,
#  'reach': 1697,
#  'inside': 1017,
#  'ate': 111,
#  'lor': 1192,
#  'gal': 767,
#  'gorgeous': 850,
#  'keep': 1067,
#  'pix': 1582,
#  'thank': 2101,
#  'say': 1799,
#  'fantastic': 665,
#  'chance': 316,
#  'anything': 71,
#  'need': 1411,
#  'life': 1147,
#  'lift': 1149,
#  'losing': 1197,
#  'live': 1167,
#  'think': 2112,
#  'first': 702,
#  'person': 1555,
#  'die': 531,
#  'usual': 2297,
#  'guy': 887,
#  'last': 1103,
#  'anybody': 68,
#  'let': 1139,
#  'throw': 2127,
#  'last night': 1104,
#  'let know': 1141,
#  'crazy': 448,
#  'world': 2440,
#  'nokia': 1442,
#  'win': 2409,
#  'auction': 116,
#  'part': 1533,
#  'send': 1836,
#  'hg': 933,
#  'suite': 2024,
#  'land': 1094,
#  'row': 1774,
#  'nokia get': 1444,
#  'take part': 2054,
#  'hg suite': 934,
#  'suite land': 2025,
#  'land row': 1096,
#  'almost': 50,
#  'see': 1818,
#  'sec': 1812,
#  'bad': 139,
#  'finger': 699,
#  'train': 2188,
#  'play': 1589,
#  'fifteen': 682,
#  'min': 1300,
#  'haf': 891,
#  'wat': 2356,
#  'wat time': 2358,
#  'lot': 1199,
#  'hospital': 967,
#  'medical': 1276,
#  'safe': 1784,
#  'fuck': 758,
#  'miss': 1315,
#  'money': 1351,
#  'towards': 2185,
#  'net': 1416,
#  'crave': 447,
#  'miss already': 1316,
#  'happened': 904,
#  'wow': 2450,
#  'mean': 1271,
#  'guess': 886,
#  'gave': 772,
#  'boston': 204,
#  'men': 1287,
#  'changed': 320,
#  'search': 1809,
#  'location': 1173,
#  'cuz': 472,
#  'page': 1526,
#  'customer': 467,
#  'service': 1851,
#  'representative': 1745,
#  'freephone': 743,
#  'pm': 1607,
#  'guaranteed': 878,
#  'cash': 301,
#  'prize': 1652,
#  'please call': 1593,
#  'call customer': 251,
#  'customer service': 469,
#  'service representative': 1853,
#  'pm guaranteed': 1609,
#  'guaranteed cash': 880,
#  'cash prize': 306,
#  'tot': 2180,
#  'juz': 1063,
#  'oni': 1498,
#  'yet': 2488,
#  'chikku': 335,
#  'abt': 4,
#  'tht': 2129,
#  'stopped': 2003,
#  'yet chikku': 2489,
#  'wat abt': 2357,
#  'forgot': 720,
#  'shall': 1862,
#  'morning': 1357,
#  'wine': 2412,
#  'pie': 1576,
#  'sleep': 1907,
#  'well': 2388,
#  'sleep well': 1908,
#  'wa': 2329,
#  'gee': 779,
#  'thanx': 2105,
#  'whole': 2401,
#  'screaming': 1807,
#  'hair': 895,
#  'loving': 1215,
#  'art': 100,
#  'college': 379,
#  'prob': 1657,
#  'email': 604,
#  'account': 8,
#  'number': 1462,
#  'probably': 1658,
#  'yeah probably': 2479,
#  'smile': 1917,
#  'tear': 2070,
#  'heart': 921,
#  'like': 1152,
#  'mine': 1308,
#  'wil': 2407,
#  'care': 295,
#  'ur smile': 2275,
#  'ur heart': 2262,
#  'master': 1256,
#  'oso': 1516,
#  'boring': 201,
#  'happy': 908,
#  'birthday': 177,
#  'dream': 572,
#  'true': 2197,
#  'happy birthday': 909,
#  'lunch': 1226,
#  'aft': 28,
#  'dat': 488,
#  'str': 2007,
#  'orchard': 1511,
#  'baby': 136,
#  'promise': 1663,
#  'treat': 2192,
#  'good care': 838,
#  'talking': 2059,
#  'fat': 671,
#  'press': 1643,
#  'also': 55,
#  'feel': 677,
#  'yesterday': 2487,
#  'til': 2136,
#  'convey': 425,
#  'wish': 2414,
#  'nimya': 1437,
#  'pls convey': 1599,
#  'convey birthday': 426,
#  'birthday wish': 178,
#  'wish nimya': 2415,
#  'nimya pls': 1438,
#  'today birthday': 2158,
#  'hey': 931,
#  'big': 173,
#  'deal': 504,
#  'take care': 2053,
#  'balance': 142,
#  'currently': 462,
#  'pound': 1632,
#  'maximize': 1266,
#  'msg': 1373,
#  'cc': 311,
#  'hl': 944,
#  'ur cash': 2257,
#  'cash balance': 303,
#  'balance currently': 143,
#  'currently pound': 463,
#  'pound maximize': 1633,
#  'maximize ur': 1267,
#  'cash send': 307,
#  'send go': 1838,
#  'go msg': 819,
#  'msg cc': 1374,
#  'row hl': 1775,
#  'th': 2098,
#  'campus': 286,
#  'atm': 112,
#  'could': 439,
#  'hour': 971,
#  'two': 2215,
#  'oops': 1502,
#  'shower': 1877,
#  'called': 268,
#  'stuff': 2014,
#  'happen': 903,
#  'need get': 1413,
#  'quick': 1674,
#  'question': 1673,
#  'lol': 1180,
#  'knew': 1084,
#  'saw': 1798,
#  'dollar': 556,
#  'store': 2005,
#  'empty': 606,
#  'without': 2420,
#  'eye': 657,
#  'amp': 58,
#  'frnds': 757,
#  'touch': 2182,
#  'sweet': 2045,
#  'empty without': 607,
#  'good night': 844,
#  'sweet dream': 2046,
#  'difficult': 535,
#  'yo': 2493,
#  'stock': 1991,
#  'tomorrow': 2167,
#  'trying': 2203,
#  'trying get': 2206,
#  'hows': 975,
#  'leaving': 1128,
#  'purity': 1666,
#  'friendship': 752,
#  'smiling': 1919,
#  'reading': 1703,
#  'forwarded': 723,
#  'message': 1291,
#  'seeing': 1823,
#  'name': 1398,
#  'gud': 881,
#  'evng': 642,
#  'purity friendship': 1667,
#  'friendship two': 754,
#  'two smiling': 2216,
#  'smiling reading': 1920,
#  'reading forwarded': 1704,
#  'forwarded message': 724,
#  'message smiling': 1292,
#  'smiling seeing': 1921,
#  'seeing name': 1824,
#  'name gud': 1400,
#  'gud evng': 882,
#  'enjoy': 615,
#  'enjoy ur': 616,
#  'ur life': 2264,
#  'sitting': 1901,
#  'mu': 1379,
#  'waiting': 2334,
#  'everyone': 640,
#  'film': 689,
#  'different': 534,
#  'whatever': 2395,
#  'bored': 200,
#  'thought': 2124,
#  'id': 993,
#  'tv': 2213,
#  'exciting': 648,
#  'situation': 1902,
#  'bought': 206,
#  'egg': 598,
#  'show': 1873,
#  'haha': 892,
#  'heard': 920,
#  'text': 2088,
#  'god': 825,
#  'created': 450,
#  'gap': 769,
#  'sum': 2026,
#  'vry': 2328,
#  'special': 1956,
#  'fill': 687,
#  'holding': 952,
#  'hand': 900,
#  'plz': 1606,
#  'dont': 558,
#  'leg': 1131,
#  'god created': 826,
#  'created gap': 451,
#  'fill gap': 688,
#  'gap holding': 770,
#  'ur hand': 2261,
#  'lt': 1217,
#  'gt': 868,
#  'bus': 233,
#  'lt gt': 1219,
#  'sad': 1779,
#  'cover': 442,
#  'face': 659,
#  'kiss': 1082,
#  'babe love': 135,
#  'project': 1662,
#  'pa': 1522,
#  'small': 1916,
#  'kid': 1078,
#  'secret': 1814,
#  'energy': 612,
#  'ah': 34,
#  'btw': 227,
#  'wana': 2343,
#  'office': 1474,
#  'wonder': 2431,
#  'sore': 1943,
#  'worse': 2444,
#  'dude': 579,
#  'always': 56,
#  'party': 1535,
#  'file': 686,
#  'three': 2125,
#  'drug': 578,
#  'dey': 527,
#  'laugh': 1118,
#  'meanwhile': 1274,
#  'darling': 486,
#  'password': 1539,
#  'uncle': 2239,
#  'new': 1423,
#  'year': 2480,
#  'abiola': 2,
#  'happy new': 911,
#  'new year': 1428,
#  'march': 1251,
#  'ending': 610,
#  'problem': 1660,
#  'never': 1422,
#  'complete': 399,
#  'far': 668,
#  'lady': 1092,
#  'arrange': 96,
#  'boy': 213,
#  'loved': 1210,
#  'bt': 225,
#  'didnt': 529,
#  'decided': 511,
#  'hit': 942,
#  'ran': 1686,
#  'hell': 925,
#  'asked': 106,
#  'hw': 990,
#  'fast': 669,
#  'replied': 1736,
#  'moral': 1356,
#  'story': 2006,
#  'hv': 989,
#  'ni': 1432,
#  'free msg': 736,
#  'gud ni': 884,
#  'nice': 1433,
#  'nice day': 1434,
#  'day dear': 495,
#  'immediately': 1004,
#  'lesson': 1138,
#  'come pick': 388,
#  'blank': 186,
#  'finish': 700,
#  'fancy': 664,
#  'meetin': 1278,
#  'wiv': 2421,
#  'tonite': 2176,
#  'break': 217,
#  'hr': 979,
#  'nite': 1439,
#  'mid': 1295,
#  'normal': 1454,
#  'fb': 674,
#  'couple': 440,
#  'minute': 1309,
#  'dun': 581,
#  'rem': 1729,
#  'black': 184,
#  'one': 1496,
#  'set': 1854,
#  'hella': 926,
#  'gas': 771,
#  'grand': 860,
#  'nature': 1403,
#  'little': 1166,
#  'want go': 2348,
#  'okie': 1491,
#  'okie lor': 1492,
#  'lor go': 1194,
#  'back': 137,
#  'come back': 386,
#  'exactly': 644,
#  'anyways': 78,
#  'study': 2012,
#  'jamster': 1045,
#  'apply': 83,
#  'get free': 786,
#  'help call': 929,
#  'time coming': 2139,
#  'either': 600,
#  'boytoy': 214,
#  'geeee': 780,
#  'bed': 160,
#  'boo': 197,
#  'mom': 1347,
#  'xx': 2469,
#  'luv': 1229,
#  'others': 1517,
#  'pls dont': 1600,
#  'goodmorning': 847,
#  'goodmorning today': 848,
#  'today late': 2160,
#  'even': 634,
#  'fun': 763,
#  'dont know': 559,
#  'teacher': 2068,
#  'longer': 1185,
#  'cut': 470,
#  'short': 1871,
#  'missing': 1322,
#  'sent': 1844,
#  'date': 489,
#  'thats': 2106,
#  'everything': 641,
#  'via': 2310,
#  'fullonsms': 761,
#  'com': 382,
#  'missing sent': 1323,
#  'sent via': 1846,
#  'fullonsms com': 762,
#  'tc': 2063,
#  'class': 354,
#  'like lt': 1156,
#  'gt minute': 875,
#  'use': 2291,
#  'bitch': 181,
#  'motorola': 1362,
#  'mths': 1377,
#  'price': 1646,
#  'linerental': 1161,
#  'txt': 2217,
#  'mobileupd': 1342,
#  'optout': 1509,
#  'nokia motorola': 1446,
#  'price linerental': 1648,
#  'call mobileupd': 261,
#  'mobileupd call': 1343,
#  'call optout': 262,
#  'better': 170,
#  'bathe': 148,
#  'book': 198,
#  'people': 1546,
#  'de': 501,
#  'happiness': 907,
#  'meet': 1277,
#  'pain': 1528,
#  'de happiness': 502,
#  'jay': 1047,
#  'fucking': 759,
#  'till': 2137,
#  'directly': 542,
#  'goto': 856,
#  'doctor': 551,
#  'wait till': 2332,
#  'congrats': 409,
#  'mail': 1236,
#  'thru': 2128,
#  'respect': 1749,
#  'mother': 1361,
#  'check': 330,
#  'staying': 1985,
#  'town': 2186,
#  'sometimes': 1935,
#  'someone': 1931,
#  'bcoz': 152,
#  'liked': 1157,
#  'bslvyl': 224,
#  'getting': 793,
#  'damn': 481,
#  'beautiful': 156,
#  'intelligent': 1020,
#  'wife': 2406,
#  'wonderful': 2433,
#  'cost': 434,
#  'info': 1014,
#  'chance win': 318,
#  'win cash': 2410,
#  'reply hl': 1740,
#  'hl info': 945,
#  'anyway': 76,
#  'character': 321,
#  'understanding': 2241,
#  'full': 760,
#  'joke': 1055,
#  'school': 1804,
#  'seem': 1825,
#  'holla': 956,
#  'friend': 747,
#  'valentine': 2301,
#  'tell friend': 2078,
#  'valentine day': 2302,
#  'havent': 917,
#  'dad': 478,
#  'went': 2393,
#  'cant': 289,
#  'cum': 458,
#  'thinking': 2119,
#  'red': 1720,
#  'green': 865,
#  'save': 1797,
#  'bos': 202,
#  'told': 2165,
#  'fixed': 706,
#  'kept': 1072,
#  'telling': 2080,
#  'etc': 630,
#  'go get': 814,
#  'missed': 1320,
#  'missed call': 1321,
#  'sexy': 1858,
#  'single': 1894,
#  'age': 32,
#  'gay': 773,
#  'started': 1979,
#  'request': 1747,
#  'came': 278,
#  'double': 565,
#  'coin': 372,
#  'gotta': 857,
#  'came back': 279,
#  'style': 2016,
#  'freemsg': 742,
#  'xmas': 2467,
#  'tone': 2168,
#  'real': 1706,
#  'tone reply': 2171,
#  'another': 64,
#  'done': 557,
#  'tried': 2193,
#  'sm': 1913,
#  'video': 2311,
#  'unlimited': 2244,
#  'camcorder': 276,
#  'call reply': 265,
#  'min unlimited': 1305,
#  'unlimited text': 2245,
#  'text free': 2092,
#  'free camcorder': 731,
#  'camcorder reply': 277,
#  'reply call': 1738,
#  'need crave': 1412,
#  'able': 3,
#  'contact': 415,
#  'response': 1750,
#  'offer': 1470,
#  'fone': 714,
#  'delivery': 520,
#  'tried contact': 2194,
#  'offer new': 1473,
#  'new nokia': 1426,
#  'ice': 992,
#  'per': 1547,
#  'post': 1629,
#  'hurt': 988,
#  'end': 608,
#  'rose': 1772,
#  'stupid': 2015,
#  'parent': 1530,
#  'new job': 1424,
#  'sorry call': 1945,
#  'call later': 258,
#  'ok prob': 1485,
#  'dropped': 577,
#  'dating': 490,
#  'po': 1611,
#  'box': 209,
#  'wu': 2455,
#  'someone know': 1932,
#  'dating service': 491,
#  'po box': 1612,
#  'friday': 746,
#  'wot': 2447,
#  'become': 158,
#  'cant wait': 292,
#  'sir': 1897,
#  'waiting call': 2335,
#  'reference': 1723,
#  'arrive': 98,
#  'thanks ringtone': 2104,
#  'ringtone order': 1763,
#  'order reference': 1513,
#  'reference number': 1724,
#  'number mobile': 1465,
#  'charged tone': 326,
#  'tone arrive': 2169,
#  'arrive please': 99,
#  'sch': 1803,
#  'neva': 1421,
#  'st': 1970,
#  'asks': 109,
#  'information': 1015,
#  'pin': 1580,
#  'share': 1863,
#  'figure': 685,
#  'trust': 2200,
#  'trying figure': 2205,
#  'disturb': 547,
#  'inch': 1009,
#  'pleasure': 1595,
#  'omg': 1494,
#  'watching': 2360,
#  'watching tv': 2361,
#  'got new': 855,
#  'pay': 1541,
#  'rent': 1734,
#  'bank': 144,
#  'try': 2202,
#  'ad': 16,
#  'ya': 2472,
#  'nxt': 1468,
#  'il': 999,
#  'ave': 119,
#  'phone': 1564,
#  'receiving': 1717,
#  'quality': 1671,
#  'miss call': 1318,
#  'laid': 1093,
#  'dogging': 554,
#  'direct': 541,
#  'mob': 1330,
#  'join': 1053,
#  'network': 1418,
#  'txting': 2227,
#  'nt': 1458,
#  'ec': 595,
#  'want get': 2347,
#  'tonight want': 2175,
#  'sent direct': 1845,
#  'ur mob': 2268,
#  'join uk': 1054,
#  'arm': 92,
#  'sound': 1949,
#  'cold': 373,
#  'sound like': 1950,
#  'man': 1244,
#  'wk': 2422,
#  'gr': 858,
#  'polys': 1624,
#  'poly': 1622,
#  'wk txt': 2423,
#  'txt nokia': 2219,
#  'nokia tone': 1448,
#  'umma': 2235,
#  'card': 294,
#  'travel': 2191,
#  'gone': 833,
#  'buck': 228,
#  'dont think': 562,
#  'think need': 2116,
#  'gt buck': 869,
#  'brand': 215,
#  'barely': 145,
#  'warm': 2354,
#  'bringing': 220,
#  'sunshine': 2032,
#  'content': 423,
#  'mobile content': 1335,
#  'princess': 1649,
#  'wun': 2456,
#  'angry': 60,
#  'come home': 387,
#  'kind': 1079,
#  'love much': 1208,
#  'mate': 1259,
#  'hi': 935,
#  'tuition': 2211,
#  'paid': 1527,
#  'semester': 1835,
#  'change': 319,
#  'sorry da': 1946,
#  'shoot': 1868,
#  'nope': 1451,
#  'accept': 6,
#  'one day': 1497,
#  'gift': 797,
#  'didnt get': 530,
#  'sooner': 1942,
#  'fix': 705,
#  'cause': 309,
#  'might': 1297,
#  'second': 1813,
#  'hey babe': 932,
#  'hard': 912,
#  'xxx': 2470,
#  'vikky': 2314,
#  'kano': 1064,
#  'theatre': 2108,
#  'wit': 2417,
#  'site': 1900,
#  'test': 2087,
#  'tough': 2183,
#  'nah': 1396,
#  'goin': 828,
#  'vl': 2318,
#  'ta': 2051,
#  'mum': 1381,
#  'needed': 1415,
#  'cant pick': 291,
#  'pick phone': 1572,
#  'phone right': 1568,
#  'right pls': 1760,
#  'pls send': 1603,
#  'send message': 1839,
#  'shd': 1864,
#  'ard': 89,
#  'add': 17,
#  'goodnight': 849,
#  'flat': 708,
#  'seems': 1827,
#  'away': 131,
#  'woman': 2430,
#  'next': 1430,
#  'space': 1953,
#  'remember': 1731,
#  'move': 1364,
#  'key': 1076,
#  'yijue': 2491,
#  'meeting': 1279,
#  'decimal': 512,
#  'pay lt': 1543,
#  'lt decimal': 1218,
#  'decimal gt': 513,
#  'season': 1811,
#  'unsubscribe': 2248,
#  'package': 1525,
#  'term': 2085,
#  'themob': 2109,
#  'map': 1250,
#  'argument': 91,
#  'experience': 652,
#  'understand': 2240,
#  'voice': 2322,
#  'still need': 1990,
#  'admirer': 20,
#  'reveal': 1754,
#  'opt': 1508,
#  'stop': 1995,
#  'recd': 1711,
#  'cust': 464,
#  'secret admirer': 1815,
#  'reveal think': 1755,
#  'special call': 1958,
#  'per msg': 1551,
#  'huh': 984,
#  'tt': 2208,
#  'choice': 339,
#  'den': 523,
#  'pissed': 1581,
#  'sister': 1898,
#  'word': 2436,
#  'model': 1345,
#  'num': 1461,
#  'ur phone': 2273,
#  'worry': 2443,
#  'photo': 1569,
#  'checking': 332,
#  'iq': 1034,
#  'every': 637,
#  'txtin': 2225,
#  'tone ur': 2173,
#  'mob every': 1331,
#  'every week': 638,
#  'week txt': 2380,
#  'st tone': 1971,
#  'tone free': 2170,
#  'free get': 734,
#  'get txtin': 789,
#  'txtin tell': 2226,
#  'tell ur': 2079,
#  'ur friend': 2260,
#  'friend tone': 751,
#  'christmas': 341,
#  'merry': 1289,
#  'tmr': 2152,
#  'lar': 1102,
#  'aiya': 43,
#  'sheet': 1865,
#  'imma': 1003,
#  'definitely': 517,
#  'interested': 1021,
#  'buying': 237,
#  'next week': 1431,
#  'reached': 1699,
#  'kick': 1077,
#  'hurry': 987,
#  'intro': 1025,
#  'selling': 1834,
#  'greet': 866,
#  'hi hi': 939,
#  ...}

# %%
X_train.shape
# Out:
# (4457, 2500)

# %%
from sklearn.naive_bayes import MultinomialNB
spam_detect_model = MultinomialNB().fit(X_train, y_train)

# %%
#predicting the output
y_pred=spam_detect_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9775784753363229

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       955
#            1       0.99      0.85      0.92       160
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.92      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[954,   1],
#        [ 24, 136]], dtype=int64)
